# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.tools import tool
from langchain_core.messages import HumanMessage
import requests

# %%
@tool
def multiply(a:int,b:int) -> int:
    """Given 2 numbers a and b this tool returns their product"""
    return a * b

# %%
multiply.invoke({'a':3,'b':9})
# Out:
# 27

# %%
multiply.name
# Out:
# 'multiply'

# %%
multiply.description
# Out:
# 'Given 2 numbers a and b this tool returns their product'

# %%
multiply.args
# Out:
# {'a': {'title': 'A', 'type': 'integer'},
#  'b': {'title': 'B', 'type': 'integer'}}

# %%
llm=ChatGoogleGenerativeAI(model='gemini-2.5-flash')

# %%
llm = llm.bind_tools([multiply])

# %%
query = HumanMessage('can yo multiply 3 with 10')

# %%
messages = [query]

# %%
messages
# Out:
# [HumanMessage(content='can yo multiply 3 with 10', additional_kwargs={}, response_metadata={})]

# %%
result = llm.invoke(messages)

# %%
messages.append(result)

# %%
messages
# Out:
# [HumanMessage(content='can yo multiply 3 with 10', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='', additional_kwargs={'function_call': {'name': 'multiply', 'arguments': '{"b": 10, "a": 3}'}, '__gemini_function_call_thought_signatures__': {'d9572c48-7d68-4b83-9f75-e65920af6c0a': ''}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f64f7-7d9e-7352-9cac-f530880f9db4-0', tool_calls=[{'name': 'multiply', 'args': {'b': 10, 'a': 3}, 'id': 'd9572c48-7d68-4b83-9f75-e65920af6c0a', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 63, 'output_tokens': 68, 'total_tokens': 131, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 49}})]

# %%
tool_result = multiply.invoke(result.tool_calls[0])

# %%
messages.append(tool_result)

# %%
messages
# Out:
# [HumanMessage(content='can yo multiply 3 with 10', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='', additional_kwargs={'function_call': {'name': 'multiply', 'arguments': '{"b": 10, "a": 3}'}, '__gemini_function_call_thought_signatures__': {'d9572c48-7d68-4b83-9f75-e65920af6c0a': ''}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f64f7-7d9e-7352-9cac-f530880f9db4-0', tool_calls=[{'name': 'multiply', 'args': {'b': 10, 'a': 3}, 'id': 'd9572c48-7d68-4b83-9f75-e65920af6c0a', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 63, 'output_tokens': 68, 'total_tokens': 131, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 49}}),
#  ToolMessage(content='30', name='multiply', tool_call_id='d9572c48-7d68-4b83-9f75-e65920af6c0a')]

# %%
llm.invoke(messages)
# Out:
# AIMessage(content='The product of 3 and 10 is 30.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f64f7-83b6-7d31-8a1c-5e73bbb1aa49-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 96, 'output_tokens': 14, 'total_tokens': 110, 'input_token_details': {'cache_read': 0}})
