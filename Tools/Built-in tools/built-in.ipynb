# %% [markdown]
# # Built-in Tool - DuckDuckGo Search

# %%
from langchain_community.tools import DuckDuckGoSearchRun

search_tool = DuckDuckGoSearchRun()

results = search_tool.invoke('ipl 2026')

print(results)
# Out:
# The 2026 Indian Premier League, also known as IPL 19 and branded as TATA IPL 2026, was the 19th edition of the Indian Premier League, a professional Twenty20 cricket league. The tournament featured 10 teams competing in 74 matches from 28 March to 31 May across 13 venues. The 2026 Indian Premier League (IPL), branded as TATA IPL 2026, is the nineteenth season of the professional Twenty20 cricket league organized annually by the Board of Control for Cricket in India (BCCI), featuring ten franchise teams in a total of… The official IPL website with live scores, match updates, team rankings, all the latest news, and videos . Follow your favorite teams and players! Full IPL | Indian Premier League 2026 Schedule, Points Table, Final Teams List, News, Venue Details, Series & Player Stats, Videos for every Indian Premier League 2026 match on... Get full coverage of IPL 2026 with live cricket scores, latest match results, and the updated points table. Get ball-by-ball commentary, player stats, match reports, and breaking news from the Indian Premier League.

# %% [markdown]
# # Built-in Tool - Shell Tool

# %%
from langchain_community.tools import ShellTool

shell_tool = ShellTool()

results = shell_tool.invoke('ls')

print(results)
# Out:
# Executing command:
#  ls
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.
